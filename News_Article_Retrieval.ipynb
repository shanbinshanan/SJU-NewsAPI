# %%
import requests
import pandas as pd
import os
import json

# API Key and Base URL
API_KEY = "87849c17e14a4d4ba4b577cdbb004b61"
BASE_URL = "https://newsapi.org/v2/top-headlines"

# Categories 
CATEGORIES = ["health", "business", "finance", "politics", "news"]
TOTAL_ARTICLES = 400

# Function to fetch news articles from NewsAPI
def fetch_news(category, page_size):
    params = {
        "category": category,
        "language": "en",
        "pageSize": page_size,
        "apiKey": API_KEY,
    }
    
    response = requests.get(BASE_URL, params=params)
    if response.status_code == 200:
        return response.json().get("articles", [])
    else:
        print(f"Error fetching data for {category}: {response.status_code}")
        return []

# Fetch articles
all_articles = []
per_category_limit = TOTAL_ARTICLES // len(CATEGORIES)  #Divide evenly

for category in CATEGORIES:
    articles = fetch_news(category, per_category_limit)
    for article in articles:
        article["category"] = category  # Add category to each article
    all_articles.extend(articles)

# Convert to DataFrame
df = pd.DataFrame(all_articles)

# Data Cleaning
df = df.drop(columns=["source", "urlToImage", "content"], errors="ignore")  # Remove unwanted columns
df = df.drop_duplicates(subset=["title"])  # Remove duplicate titles
df = df.dropna(subset=["title", "description", "url"])  # Remove rows with missing data

# Limit to 300 articles 
df = df.head(TOTAL_ARTICLES)

# Display the cleaned DataFrame
df.index = range(1, len(df) + 1)  
display(df)

# Create a folder to store JSON files 
FOLDER_NAME = "news_articles"
os.makedirs(FOLDER_NAME, exist_ok=True)

# Save each article as a JSON file
for idx, article in df.iterrows():
    # Convert row to dictionary
    article_dict = article.to_dict()

    # Define JSON file path 
    file_path = os.path.join(FOLDER_NAME, f"article_{idx + 1}.json")

    # Save as JSON
    with open(file_path, "w", encoding="utf-8") as json_file:
        json.dump(article_dict, json_file, indent=4)

    print(f"Saved: {file_path}")

print(f" All {len(df)} articles saved as JSON files in the '{FOLDER_NAME}' folder.")
# Out:
#               author                                              title  \
# 1     Rhiannon Ingle  Everything that happens to your body if you st...
# 2        Kamal Nahas  We may finally understand how metformin lowers...
# 3     Carrie Dennett  Are ultraprocessed foods the dietary demons th...
# 4               None  Is Fluoride Lowering Children’s IQ? New Resear...
# 5               None  Sounds Like Science Fiction: Doctors Implant a...
# ..               ...                                                ...
# 111         Tim Benz  Tim Benz: How I want the Steelers' dominoes to...
# 112     Jamie Carter  This month's 'blood moon' eclipse mirrors one ...
# 113  Neal Augenstein  Family of missing Loudoun Co. college student ...
# 114     Jason Bittel  Maybe megalodon wasn’t so chonky after all - N...
# 115   Will Conybeare  4.1-magnitude earthquake jolts Los Angeles are...
#
#                                            description  \
# 1    There are a number of health benefits to havin...
# 2    The common diabetes drug metformin works partl...
# 3    Registered dietitian nutritionist Carrie Denne...
# 4    Fluoride is added to drinking water in many co...
# 5    Doctors in Canada have just performed a surger...
# ..                                                 ...
# 111  I like the Pittsburgh Steelers&rsquo; decision...
# 112  On March 13-14, 2025, skywatchers in the Ameri...
# 113  The father of 20-year-old Sudiksha Konanki, of...
# 114  A new study proposes that the massive ancient ...
# 115  An earthquake with a magnitude of 4.1 rattled ...
#
#                                                    url           publishedAt  \
# 1    https://www.tyla.com/life/sex-and-relationship...  2025-03-10T14:52:26Z
# 2    https://www.livescience.com/health/diabetes/we...  2025-03-10T14:40:00Z
# 3    https://www.seattletimes.com/life/wellness/are...  2025-03-10T13:00:00Z
# 4    https://scitechdaily.com/is-fluoride-lowering-...  2025-03-10T12:31:30Z
# 5    https://dailygalaxy.com/2025/03/sounds-like-sc...  2025-03-10T12:20:00Z
# ..                                                 ...                   ...
# 111  https://triblive.com/sports/tim-benz-how-i-wan...  2025-03-10T10:28:00Z
# 112  https://www.space.com/march-2025-eclipse-echoe...  2025-03-10T10:00:00Z
# 113  https://wtop.com/loudoun-county/2025/03/family...  2025-03-10T09:00:56Z
# 114  https://www.nationalgeographic.com/science/art...  2025-03-09T23:18:19Z
# 115  https://ktla.com/news/california/latest-earthq...  2025-03-09T20:09:26Z
#
#      category
# 1      health
# 2      health
# 3      health
# 4      health
# 5      health
# ..        ...
# 111  politics
# 112  politics
# 113  politics
# 114  politics
# 115  politics
#
# [115 rows x 6 columns]
# Saved: news_articles/article_2.json
# Saved: news_articles/article_3.json
# Saved: news_articles/article_4.json
# Saved: news_articles/article_5.json
# Saved: news_articles/article_6.json
# Saved: news_articles/article_7.json
# Saved: news_articles/article_8.json
# Saved: news_articles/article_9.json
# Saved: news_articles/article_10.json
# Saved: news_articles/article_11.json
# Saved: news_articles/article_12.json
# Saved: news_articles/article_13.json
# Saved: news_articles/article_14.json
# Saved: news_articles/article_15.json
# Saved: news_articles/article_16.json
# Saved: news_articles/article_17.json
# Saved: news_articles/article_18.json
# Saved: news_articles/article_19.json
# Saved: news_articles/article_20.json
# Saved: news_articles/article_21.json
# Saved: news_articles/article_22.json
# Saved: news_articles/article_23.json
# Saved: news_articles/article_24.json
# Saved: news_articles/article_25.json
# Saved: news_articles/article_26.json
# Saved: news_articles/article_27.json
# Saved: news_articles/article_28.json
# Saved: news_articles/article_29.json
# Saved: news_articles/article_30.json
# Saved: news_articles/article_31.json
# Saved: news_articles/article_32.json
# Saved: news_articles/article_33.json
# Saved: news_articles/article_34.json
# Saved: news_articles/article_35.json
# Saved: news_articles/article_36.json
# Saved: news_articles/article_37.json
# Saved: news_articles/article_38.json
# Saved: news_articles/article_39.json
# Saved: news_articles/article_40.json
# Saved: news_articles/article_41.json
# Saved: news_articles/article_42.json
# Saved: news_articles/article_43.json
# Saved: news_articles/article_44.json
# Saved: news_articles/article_45.json
# Saved: news_articles/article_46.json
# Saved: news_articles/article_47.json
# Saved: news_articles/article_48.json
# Saved: news_articles/article_49.json
# Saved: news_articles/article_50.json
# Saved: news_articles/article_51.json
# Saved: news_articles/article_52.json
# Saved: news_articles/article_53.json
# Saved: news_articles/article_54.json
# Saved: news_articles/article_55.json
# Saved: news_articles/article_56.json
# Saved: news_articles/article_57.json
# Saved: news_articles/article_58.json
# Saved: news_articles/article_59.json
# Saved: news_articles/article_60.json
# Saved: news_articles/article_61.json
# Saved: news_articles/article_62.json
# Saved: news_articles/article_63.json
# Saved: news_articles/article_64.json
# Saved: news_articles/article_65.json
# Saved: news_articles/article_66.json
# Saved: news_articles/article_67.json
# Saved: news_articles/article_68.json
# Saved: news_articles/article_69.json
# Saved: news_articles/article_70.json
# Saved: news_articles/article_71.json
# Saved: news_articles/article_72.json
# Saved: news_articles/article_73.json
# Saved: news_articles/article_74.json
# Saved: news_articles/article_75.json
# Saved: news_articles/article_76.json
# Saved: news_articles/article_77.json
# Saved: news_articles/article_78.json
# Saved: news_articles/article_79.json
# Saved: news_articles/article_80.json
# Saved: news_articles/article_81.json
# Saved: news_articles/article_82.json
# Saved: news_articles/article_83.json
# Saved: news_articles/article_84.json
# Saved: news_articles/article_85.json
# Saved: news_articles/article_86.json
# Saved: news_articles/article_87.json
# Saved: news_articles/article_88.json
# Saved: news_articles/article_89.json
# Saved: news_articles/article_90.json
# Saved: news_articles/article_91.json
# Saved: news_articles/article_92.json
# Saved: news_articles/article_93.json
# Saved: news_articles/article_94.json
# Saved: news_articles/article_95.json
# Saved: news_articles/article_96.json
# Saved: news_articles/article_97.json
# Saved: news_articles/article_98.json
# Saved: news_articles/article_99.json
# Saved: news_articles/article_100.json
# Saved: news_articles/article_101.json
# Saved: news_articles/article_102.json
# Saved: news_articles/article_103.json
# Saved: news_articles/article_104.json
# Saved: news_articles/article_105.json
# Saved: news_articles/article_106.json
# Saved: news_articles/article_107.json
# Saved: news_articles/article_108.json
# Saved: news_articles/article_109.json
# Saved: news_articles/article_110.json
# Saved: news_articles/article_111.json
# Saved: news_articles/article_112.json
# Saved: news_articles/article_113.json
# Saved: news_articles/article_114.json
# Saved: news_articles/article_115.json
# Saved: news_articles/article_116.json
#  All 115 articles saved as JSON files in the 'news_articles' folder.
